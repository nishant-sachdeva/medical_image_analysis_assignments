# %%
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
def calculate_psnr(img1, img2):
    # img1 and img2 have range [0, 255]
    img1 = img1.astype(np.float64)
    img2 = img2.astype(np.float64)
    mse = np.mean((img1 - img2)**2)
    if mse == 0:
        return float('inf')
    return 20 * math.log10(255.0 / math.sqrt(mse))

# %%
# question 1 : 
# Perona Malik and Black Algorithm

def perona_malik_1d( grad_value, K ) :
    # perona malik  can depend on the values of X and K 
    return 1 + 1/ (1 + (grad_value/k)**2 )

def perona_malik_2d(grad_value, K):
    return np.exp(-((grad_value/k)**2))


def black(grad_value, K):
    return 1 - 2*((grad_value**2) / (k**2))

# %%
# Question 1 plotting of the data
import random
gradient_values = np.linspace(0, 10, num=100)

K = random.sample(range(1, 10), 6)

plt.subplot(311)
plt.title("Perona Malik 1D")
for k in K:
    plt.plot(gradient_values, perona_malik_1d(gradient_values, k),label=f'K={K}')

plt.subplot(312)
plt.title("Perona Malik 2D")
for k in K:
    plt.plot(gradient_values, perona_malik_2d(gradient_values, k),label=f'K={K}')

plt.subplot(313)
plt.title("Black et all")
for k in K:
    plt.plot(gradient_values, black(gradient_values, k),label=f'K={K}')


plt.tight_layout()
plt.show()

# %%
# Question 1 B 
# Having to implement the diffusion filtering \ smoothing on the given images
# !pip3 install ants
# Out:
# Collecting ants
#   Downloading https://files.pythonhosted.org/packages/97/1a/71d058169f353007d21afa242a4a1490604af31c3888f8beec5a82f007cd/ants-0.0.7.tar.gz
# Collecting Django>=1.10.2 (from ants)
#   Downloading https://files.pythonhosted.org/packages/b8/6f/9a4415cc4fe9228e26ea53cf2005961799b2abb8da0411e519fdb74754fa/Django-3.1.7-py3-none-any.whl (7.8MB)
#     100% |████████████████████████████████| 7.8MB 259kB/s eta 0:00:01
# Collecting gevent>=1.1.1 (from ants)
#   Downloading https://files.pythonhosted.org/packages/0b/50/1b1175ea3a269b5fa3f0f7fed11149888180695bef5fbf568adbb196efaf/gevent-21.1.2.tar.gz (5.9MB)
#     100% |████████████████████████████████| 5.9MB 329kB/s eta 0:00:01
# Collecting asgiref<4,>=3.2.10 (from Django>=1.10.2->ants)
#   Downloading https://files.pythonhosted.org/packages/89/49/5531992efc62f9c6d08a7199dc31176c8c60f7b2548c6ef245f96f29d0d9/asgiref-3.3.1-py3-none-any.whl
# Collecting sqlparse>=0.2.2 (from Django>=1.10.2->ants)
#   Downloading https://files.pythonhosted.org/packages/14/05/6e8eb62ca685b10e34051a80d7ea94b7137369d8c0be5c3b9d9b6e3f5dae/sqlparse-0.4.1-py3-none-any.whl (42kB)
#     100% |████████████████████████████████| 51kB 10.9MB/s ta 0:00:01
# Collecting pytz (from Django>=1.10.2->ants)
#   Using cached https://files.pythonhosted.org/packages/70/94/784178ca5dd892a98f113cdd923372024dc04b8d40abe77ca76b5fb90ca6/pytz-2021.1-py2.py3-none-any.whl
# Collecting zope.event (from gevent>=1.1.1->ants)
#   Downloading https://files.pythonhosted.org/packages/9e/85/b45408c64f3b888976f1d5b37eed8d746b8d5729a66a49ec846fda27d371/zope.event-4.5.0-py2.py3-none-any.whl
# Collecting zope.interface (from gevent>=1.1.1->ants)
#   Downloading https://files.pythonhosted.org/packages/b8/7f/68077712fe83112d25b1ccf2e34f59e23a3cd7a54ea631090a6df77862de/zope.interface-5.2.0-cp36-cp36m-manylinux1_x86_64.whl (236kB)
#     100% |████████████████████████████████| 245kB 264kB/s ta 0:00:011
# Collecting setuptools (from gevent>=1.1.1->ants)
#   Downloading https://files.pythonhosted.org/packages/15/0e/255e3d57965f318973e417d5b7034223f1223de500d91b945ddfaef42a37/setuptools-53.0.0-py3-none-any.whl (784kB)
#     100% |████████████████████████████████| 788kB 953kB/s ta 0:00:011
# Collecting greenlet<2.0,>=0.4.17 (from gevent>=1.1.1->ants)
#   Downloading https://files.pythonhosted.org/packages/b7/3d/ad33c508d1ee8fb5d32c24986ebfd8f71df1b05e8683d1406658c62b3b25/greenlet-1.0.0-cp36-cp36m-manylinux1_x86_64.whl (156kB)
#     100% |████████████████████████████████| 163kB 2.2MB/s ta 0:00:01
# Building wheels for collected packages: ants, gevent
#   Running setup.py bdist_wheel for ants ... done
#   Stored in directory: /home/nishu/.cache/pip/wheels/7a/b9/b3/8951067e38357b9d5ab027c53d0eba0d5b56785d30b3e674cc
#   Running setup.py bdist_wheel for gevent ... done
#   Stored in directory: /home/nishu/.cache/pip/wheels/57/40/c1/7a141ba51e564a7d8065b1c9fee69f9b04cd7ac38243fc7d55
# Successfully built ants gevent
# Installing collected packages: asgiref, sqlparse, pytz, Django, setuptools, zope.event, zope.interface, greenlet, gevent, ants
# Successfully installed Django-3.1.7 ants-0.0.7 asgiref-3.3.1 gevent-21.1.2 greenlet-1.0.0 pytz-2021.1 setuptools-53.0.0 sqlparse-0.4.1 zope.event-4.5.0 zope.interface-5.2.0

# %%
# Question 2 
# Checking performance of the ONLM ,ANLM etc methods, 

# nlm will be implemented using scipy tho

from skimage import data, img_as_float
from skimage.restoration import denoise_nl_means, estimate_sigma
from skimage.metrics import peak_signal_noise_ratio
from skimage.util import random_noise

# we are going to load nii images, and then have them get put through XNLM, NLM and then we can compare results after that

import ants

image1 = ants.image_read('../MIA_A4/MRI_data/3.nii')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-e4f23075fd2c> in <module>
#      13 import ants
#      14
# ---> 15 image1 = ants.image_read('../MIA_A4/MRI_data/3.nii')
#
# AttributeError: module 'ants' has no attribute 'image_read'
